# %% [markdown]
# # 01 - Basic Setup Test
#
# **Purpose:** Verify environment is working and establish logging patterns
#
# **What we're testing:**
# - Python version (should be 3.11+)
# - Basic imports work
# - Emoji printing works
# - Jupyter kernel is functional
#
# **Next steps:** After this works, we'll test Polymarket API connections

# %%
# Cell 1: Basic Imports
print("🔍 Starting environment setup test...")
print("📦 Importing libraries...")

import sys
import platform
import asyncio
from datetime import datetime
import json

print("✅ All basic imports successful!")

# %%
# Cell 2: Check Python Version
print("🔍 Checking Python version...")
print(f"📊 Python version: {sys.version}")
print(f"📊 Python version info: {sys.version_info}")

# Verify it's 3.11+
if sys.version_info >= (3, 11):
    print("✅ Python version is 3.11+ (optimal for performance)")
elif sys.version_info >= (3, 9):
    print("⚠️ Python version is 3.9+, but 3.11+ recommended for better performance")
else:
    print("❌ Python version is too old! Need 3.9+ minimum, 3.11+ recommended")

# %%
# Cell 3: System Information
print("🔍 Gathering system information...")
print(f"📊 Platform: {platform.platform()}")
print(f"📊 System: {platform.system()}")
print(f"📊 Machine: {platform.machine()}")
print(f"📊 Processor: {platform.processor()}")
print(f"📊 Current time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("✅ System info gathered successfully!")

# %%
# Cell 4: Test Emoji Logging (Our Standard)
print("🔍 Testing emoji logging system...")
print("")
print("Emoji Legend (we'll use these throughout the project):")
print("🔍 Searching/processing")
print("✅ Success")
print("❌ Error")
print("⚠️ Warning")
print("📊 Data/stats")
print("💾 Saving")
print("🤖 AI/Ollama")
print("🌐 Network/web")
print("📄 Files")
print("💰 Trading/money")
print("⏱️ Timing/performance")
print("")
print("✅ All emojis display correctly!")

# %%
# Cell 5: Test Async Functionality
print("🔍 Testing async/await functionality...")

async def test_async():
    print("⏱️ Starting async function...")
    await asyncio.sleep(0.1)  # Simulate async operation
    print("✅ Async function completed!")
    return "Async works!"

# Run the async test
result = await test_async()
print(f"📊 Result: {result}")

# %%
# Cell 6: Summary
print("="*60)
print("🎉 SETUP TEST COMPLETE!")
print("="*60)
print("✅ Python version check: PASSED")
print("✅ Basic imports: PASSED")
print("✅ System info: PASSED")
print("✅ Emoji logging: PASSED")
print("✅ Async functionality: PASSED")
print("")
print("📋 Next steps:")
print("   1. Install Polymarket dependencies (py-clob-client, web3, etc.)")
print("   2. Set up .env file with credentials")
print("   3. Test WebSocket connection to Polymarket")
print("   4. Fetch real order book data")
print("")
print("✅ Ready to proceed!")
